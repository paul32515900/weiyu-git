# %%
import re
txt = "Go Go PowerRanger"
x = re.search('Go',txt)
x
# Out:
# <re.Match object; span=(0, 2), match='Go'>

# %%
product = 1
for x in nums:
    if not isinstance(x, (int, float)):
        # Allow numeric types that behave like numbers (e.g., Decimal) via duck typing
        try:
            product *= x
        except Exception as e:
            raise TypeError(f"Non-numeric value encountered: {x!r}") from e
    else:
        product *= x
return product
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 product = 1
# ----> 2 for x in nums:
#       3     if not isinstance(x, (int, float)):
#       4         # Allow numeric types that behave like numbers (e.g., Decimal) via duck typing
#       5         try:
#
# NameError: name 'nums' is not defined

# %%
def calAvg(target_list):
    return sum(target_list)/len(target_list)

my_list = [10, -2 ,3,8,-10 ]
print(calAvg(my_list))
# Out:
# 1.8

# %%
def has_33(nums):
    for i in range(0,len(nums)-1):
        if nums[i] == 3 and nums[i+1] == 3 :
            return True  
    return False
print("Test #1: {}".format(has_33([1, 3, 3])))
print("Test #2: {}".format(has_33([1, 3, 1, 3])))
print("Test #3: {}".format(has_33([3, 1, 3])))
# Out:
# Test #1: True
# Test #2: False
# Test #3: False

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 3000

# %%
def F(n):
    if n == 0 or n ==1 :
        return n
    else:
        return F(n-1)+F(n-2)
print(F(20))
# Out:
# 6765

# %%
def fibonacciVal(n):
    memo = [None] * (n+1)
    memo[0], memo[1] = 0, 1
    for i in range(2, n+1):
        memo[i] = memo[i-1] + memo[i-2]
    return memo[n]

print(fibonacciVal(20))
# Out:
# 6765

# %%
class Bank():
    '''定義銀行類別'''
    def __init__(self, uname):
        self.name = uname
        self.balance = 0
        self.bankname = 'Taipei Bank'
    def save_money(self, money):
        self.balance += money
        print('存款', money, "完成")
    
    def withdraw_money(self, money):
        self.balance -= money
        print("提款", money, "完成")

    def get_balance(self):
        print(self.name," 目前餘額: ", self.balance)


isaacbank = Bank('isaac')
print("目前開戶銀行", isaacbank.bankname)
isaacbank.get_balance()
isaacbank.save_money(200)
isaacbank.get_balance()
# Out:
# 目前開戶銀行 Taipei Bank
# isaac  目前餘額:  0
# 存款 200 完成
# isaac  目前餘額:  200
